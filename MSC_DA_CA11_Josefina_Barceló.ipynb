# %%
import pandas as pd

# %%
df = pd.read_csv('Travel by Irish Residents.csv')

# %%
df.head(10)
# Out:
#                       Statistic Label  Year  Domestic  \
# 0  Number of Trips by Irish Residents  2000  Domestic
# 1  Number of Trips by Irish Residents  2000  Domestic
# 2  Number of Trips by Irish Residents  2000  Domestic
# 3  Number of Trips by Irish Residents  2000  Domestic
# 4  Number of Trips by Irish Residents  2000  Domestic
# 5  Number of Trips by Irish Residents  2000  Domestic
# 6  Number of Trips by Irish Residents  2000  Domestic
# 7  Number of Trips by Irish Residents  2000  Domestic
# 8  Number of Trips by Irish Residents  2000  Outbound
# 9  Number of Trips by Irish Residents  2000  Outbound
#
#            Reason for Journey      UNIT   VALUE
# 0     All reasons for journey  Thousand  5478.0
# 1                     Holiday  Thousand  2516.0
# 2                    Business  Thousand   554.0
# 3  Visiting friends/relatives  Thousand  1800.0
# 4      Education and training  Thousand     NaN
# 5       Work/looking for work  Thousand     NaN
# ...

# %%
df.describe()
# Out:
#               Year         VALUE
# count  1472.000000   1160.000000
# mean   2011.000000   3805.177500
# std       6.635504   9292.456791
# min    2000.000000      1.600000
# 25%    2005.000000     17.975000
# 50%    2011.000000    559.000000
# 75%    2017.000000   2743.250000
# max    2022.000000  66927.000000
